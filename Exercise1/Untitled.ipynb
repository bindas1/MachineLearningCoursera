# %%
string = "g fmnc wms bgblr rpylqjyrc gr zw fylb. rfyrq ufyr amknsrcpq ypc dmp. bmgle gr gl zw fylb gq glcddgagclr ylb rfyr'q ufw rfgq rcvr gq qm jmle. sqgle qrpgle.kyicrpylq() gq pcamkkclbcb. lmu ynnjw ml rfc spj."

# %%
for letter in string:
    letter = 'a'

# %%
string2 = []

# %%
for letter in string:
    string2.append(letter+2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-6eb28b582861> in <module>
#       1 for letter in string:
# ----> 2     string2.append(letter+2)
#       3
#
# TypeError: can only concatenate str (not "int") to str

# %%
shifttext(string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-0ac5d814a2e5> in <module>
# ----> 1 shifttext(string)
#
# NameError: name 'shifttext' is not defined

# %%
def shift(s, n):
     return ''.join(chr((ord(char) - 97 + n) % 26 + 97) for char in s if isalpha)

# %%
shift(string, 2)
# Out:
# 'ihopeyoudidnttranslateitbyhanddthatswhatcomputersareforddoingitinbyhandisinefficientandthatwswhythistextissolongdusingstringdmaketransxyisrecommendeddnowapplyontheurld'

# %%
import urllib.request

# %%
html = urllib.request.urlopen("http://www.pythonchallenge.com/pc/def/ocr.html").read().decode()

# %%
html
# Out:
# '<html>\n<head>\n  <title>ocr</title>\n  <link rel="stylesheet" type="text/css" href="../style.css">\n</head>\n<body>\n<center><img src="ocr.jpg">\n<br><font color="#c03000">\nrecognize the characters. maybe they are in the book, <br>but MAYBE they \nare in the page source.</center>\n\n<br>\n<br>\n<br>\n\n<font size="-1" color="gold">\nGeneral tips:\n<li>Use the hints. They are helpful, most of the times.</li>\n<li>Investigate the data given to you.</li>\n<li>Avoid looking for spoilers.</li>\n<br>\nForums: <a href="http://www.pythonchallenge.com/forums"/>Python Challenge Forums</a>, \nread before you post.\n<br>\nIRC: irc.freenode.net #pythonchallenge\n<br><br>\nTo see the solutions to the previous level, replace pc with pcc, i.e. go \nto: http://www.pythonchallenge.com/pcc/def/ocr.html\n\n</body>\n</html>\n\n<!--\nfind rare characters in the mess below:\n-->\n\n<!--\n%%$@_$^__#)^)&!_+]!*@&^}@[@%]()%+$&[(_@%+%$*^@$^!+]!&_#)_*}{}}!}_]$[%}@[{_@#_^{*\n@##&{#&{&)*%(]{{([*}@[@&]+!!*{)!}{%
# ...

# %%
import re

# %%
comments = re.findall("<!--([\w\n]*?)-->", html)

# %%
comments
# Out:
# []

# %%
dictionary = {}

# %%
for char in data:
    if data in dictionary:
        dictionary[data] += 1
    else:
        dictionary[data] = 1

# %%
temp = min(dictionary.values())

# %%
chars = [key for key in dictionary.keys() if dictionary[key]==temp]

# %%
import urllib.request
import re
html = urllib.request.urlopen("http://www.pythonchallenge.com/pc/def/ocr.html").read().decode()
data = re.findall("<!--(.*?)-->", html, re.DOTALL)[-1]
print("".join(re.findall("[A-Za-z]", data)))
# Out:
# equality

# %%
letters = 'bartek ma kota'
letters = list(letters)

# %%
for letter in letters:
    letter = 'a'

# %%
letters
# Out:
# ['b', 'a', 'r', 't', 'e', 'k', ' ', 'm', 'a', ' ', 'k', 'o', 't', 'a']

# %%
for letter in letters:
    letter =
